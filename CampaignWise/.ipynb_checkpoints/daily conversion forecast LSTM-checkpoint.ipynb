# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, GRU, Dropout

# %%
tr_df = pd.read_csv('DailyData.csv')

# %%
tr_df.head()
# Out:
#                           campaign name        date  clicks  impressions  \
# 0  SHOPTIMISED PMax-46 - all products-M  2023-11-28       0           33
# 1  SHOPTIMISED PMax-46 - all products-M  2023-11-29      11         1139
# 2  SHOPTIMISED PMax-46 - all products-M  2023-11-30       7          655
# 3  SHOPTIMISED PMax-46 - all products-M  2023-12-01       5          684
# 4  SHOPTIMISED PMax-46 - all products-M  2023-12-02      43         3792
#
#    cost_micros      bidding_strategy_type  conversions  cost_per_conversion  \
# 0            0  MAXIMIZE_CONVERSION_VALUE     0.000000                  NaN
# 1      4060000  MAXIMIZE_CONVERSION_VALUE     1.000000          4060000.000
# 2      1430000  MAXIMIZE_CONVERSION_VALUE     0.000000                  NaN
# 3      2640000  MAXIMIZE_CONVERSION_VALUE     0.000000                  NaN
# 4     10510000  MAXIMIZE_CONVERSION_VALUE     3.332276          3154000.449
#
#    Click-through rate (CTR)  average cost per click (CPC)  \
# 0                  0.000000                      0.000000
# 1                  0.965759                      0.369091
# 2                  1.068702                      0.204286
# 3                  0.730994                      0.528000
# 4                  1.133966                      0.244419
#
#    cost-per-acquisition (CPA)   Cost  conversion per euro
# 0                    0.000000   0.00             0.000000
# 1                    4.060000   4.06             0.246305
# 2                    4.085714   1.43             0.000000
# 3                   10.560000   2.64             0.000000
# 4                    3.154000  10.51             0.317058

# %%
tr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   campaign name                 176 non-null    object
#  1   date                          176 non-null    object
#  2   clicks                        176 non-null    int64
#  3   impressions                   176 non-null    int64
#  4   cost_micros                   176 non-null    int64
#  5   bidding_strategy_type         176 non-null    object
#  6   conversions                   176 non-null    float64
#  7   cost_per_conversion           170 non-null    float64
#  8   Click-through rate (CTR)      176 non-null    float64
#  9   average cost per click (CPC)  176 non-null    float64
#  10  cost-per-acquisition (CPA)    176 non-null    float64
#  11  Cost                          176 non-null    float64
#  12  conversion per euro           176 non-null    float64
# dtypes: float64(7), int64(3), object(3)
# memory usage: 18.0+ KB

# %%
tr_df['date'] = pd.to_datetime(tr_df['date'])

# %%
tr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   campaign name                 176 non-null    object
#  1   date                          176 non-null    datetime64[ns]
#  2   clicks                        176 non-null    int64
#  3   impressions                   176 non-null    int64
#  4   cost_micros                   176 non-null    int64
#  5   bidding_strategy_type         176 non-null    object
#  6   conversions                   176 non-null    float64
#  7   cost_per_conversion           170 non-null    float64
#  8   Click-through rate (CTR)      176 non-null    float64
#  9   average cost per click (CPC)  176 non-null    float64
#  10  cost-per-acquisition (CPA)    176 non-null    float64
#  11  Cost                          176 non-null    float64
#  12  conversion per euro           176 non-null    float64
# dtypes: datetime64[ns](1), float64(7), int64(3), object(2)
# memory usage: 18.0+ KB

# %%
tr_df.set_index('date', inplace= True)

# %%
tr_df.head()
# Out:
#                                    campaign name  clicks  impressions  \
# date
# 2023-11-28  SHOPTIMISED PMax-46 - all products-M       0           33
# 2023-11-29  SHOPTIMISED PMax-46 - all products-M      11         1139
# 2023-11-30  SHOPTIMISED PMax-46 - all products-M       7          655
# 2023-12-01  SHOPTIMISED PMax-46 - all products-M       5          684
# 2023-12-02  SHOPTIMISED PMax-46 - all products-M      43         3792
#
#             cost_micros      bidding_strategy_type  conversions  \
# date
# 2023-11-28            0  MAXIMIZE_CONVERSION_VALUE     0.000000
# 2023-11-29      4060000  MAXIMIZE_CONVERSION_VALUE     1.000000
# 2023-11-30      1430000  MAXIMIZE_CONVERSION_VALUE     0.000000
# 2023-12-01      2640000  MAXIMIZE_CONVERSION_VALUE     0.000000
# 2023-12-02     10510000  MAXIMIZE_CONVERSION_VALUE     3.332276
#
#             cost_per_conversion  Click-through rate (CTR)  \
# date
# 2023-11-28                  NaN                  0.000000
# 2023-11-29          4060000.000                  0.965759
# 2023-11-30                  NaN                  1.068702
# 2023-12-01                  NaN                  0.730994
# 2023-12-02          3154000.449                  1.133966
#
#             average cost per click (CPC)  cost-per-acquisition (CPA)   Cost  \
# date
# 2023-11-28                      0.000000                    0.000000   0.00
# 2023-11-29                      0.369091                    4.060000   4.06
# 2023-11-30                      0.204286                    4.085714   1.43
# 2023-12-01                      0.528000                   10.560000   2.64
# 2023-12-02                      0.244419                    3.154000  10.51
#
#             conversion per euro
# date
# 2023-11-28             0.000000
# 2023-11-29             0.246305
# 2023-11-30             0.000000
# 2023-12-01             0.000000
# 2023-12-02             0.317058

# %% [markdown]
# # conversions Trend

# %%
plt.figure(figsize = (15, 6))
plt.plot(tr_df.index, tr_df['conversions'])
plt.xlabel('Date', {'fontsize': 12})
plt.ylabel('conversions', {'fontsize': 12})
plt.title('Number of conversions')
plt.show()

# %%
n_cols = 1
conversionsdataset = tr_df['conversions']
conversionsdataset = pd.DataFrame(conversionsdataset)
conversionsdata = conversionsdataset.values

conversionsdata.shape
# Out:
# (176, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
conversions_scaled_data = scaler.fit_transform(np.array(conversionsdata))

# %%
train_size = int(len(conversionsdata) * 0.80)
test_size = len(conversionsdata) - train_size
print("Train Size :",train_size,"Test Size :",test_size)
# Out:
# Train Size : 140 Test Size : 36

# %%
train_data = conversions_scaled_data[0:train_size, :]
train_data.shape
# Out:
# (140, 1)

# %%
# Creating a Training set with 60 time-steps and 1 target
x_train = []
y_train = []
time_steps = 30
n_cols = 1

for i in range(time_steps, len(train_data)):
    x_train.append(train_data[i-time_steps:i, :n_cols])
    y_train.append(train_data[i, :n_cols])
    if i<=time_steps:
        print('X_train: ', x_train)
        print('y_train:' , y_train)
# Out:
# X_train:  [array([[0.        ],
#        [0.07619048],
#        [0.        ],
#        [0.        ],
#        [0.2538877 ],
#        [0.07619048],
#        [0.1134851 ],
#        [0.15238095],
#        [0.26666667],
#        [0.16507939],
#        [0.41904762],
#        [0.38095238],
#        [0.34303802],
#        [0.48120663],
#        [0.58013173],
#        [0.52528731],
#        [0.38021272],
#        [0.29191566],
#        [0.68748846],
#        [0.7174029 ],
#        [0.38050842],
#        [0.30496373],
#        [0.10158735],
#        [0.03794728],
#        [0.15238095],
#        [0.        ],
#        [0.11407383],
#        [0.19393943],
#        [0.07619048],
#        [0.07619048]])]
# y_train: [array([0.07619048])]

# %%
len(x_train)
# Out:
# 110

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input to (n_samples, time_steps, n_feature)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_cols))

# %%
x_train.shape , y_train.shape
# Out:
# ((110, 30, 1), (110, 1))

# %%
model = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], n_cols)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(n_cols)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics=['mean_absolute_error'])
# Out:
# C:\Users\Digitweb Sathurjan\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 30, 50)              │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          29,440 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 42,465 (165.88 KB)
#  Trainable params: 42,465 (165.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fitting the LSTM to the Training set
callbacks = [EarlyStopping(monitor= 'loss', patience= 10 , restore_best_weights= True)]
history = model.fit(x_train, y_train, epochs= 300, batch_size= 16 , callbacks= callbacks )
# Out:
# Epoch 1/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.2067 - mean_absolute_error: 0.3679
# Epoch 2/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0605 - mean_absolute_error: 0.2075
# Epoch 3/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0515 - mean_absolute_error: 0.1700
# Epoch 4/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0573 - mean_absolute_error: 0.1951
# Epoch 5/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0563 - mean_absolute_error: 0.1921
# Epoch 6/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0475 - mean_absolute_error: 0.1769
# Epoch 7/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0510 - mean_absolute_error: 0.1823
# Epoch 8/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0434 - mean_absolute_error: 0.1672
# Epoch 9/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0466 - mean_absolute_error: 0.1675
# Epoch 10/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0425 - mean_absolute_error: 0.1636
# Epoch 11/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0508 - mean_absolute_error: 0.1846
# Epoch 12/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0501 - mean_absolute_error: 0.1794
# Epoch 13/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0453 - mean_absolute_error: 0.1696
# Epoch 14/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0538 - mean_absolute_error: 0.1800
# Epoch 15/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0499 - mean_absolute_error: 0.1790
# Epoch 16/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0507 - mean_absolute_error: 0.1807
# Epoch 17/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0513 - mean_absolute_error: 0.1815
# Epoch 18/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0444 - mean_absolute_error: 0.1651
# Epoch 19/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0469 - mean_absolute_error: 0.1734
# Epoch 20/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0480 - mean_absolute_error: 0.1759
# Epoch 21/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0463 - mean_absolute_error: 0.1708
# Epoch 22/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0423 - mean_absolute_error: 0.1646
# Epoch 23/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0565 - mean_absolute_error: 0.1918
# Epoch 24/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0451 - mean_absolute_error: 0.1717
# Epoch 25/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0469 - mean_absolute_error: 0.1770
# Epoch 26/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0505 - mean_absolute_error: 0.1815
# Epoch 27/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0465 - mean_absolute_error: 0.1784
# Epoch 28/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0481 - mean_absolute_error: 0.1771
# Epoch 29/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0505 - mean_absolute_error: 0.1744
# Epoch 30/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0457 - mean_absolute_error: 0.1732
# Epoch 31/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0489 - mean_absolute_error: 0.1772
# Epoch 32/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0507 - mean_absolute_error: 0.1781
# Epoch 33/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0479 - mean_absolute_error: 0.1798
# Epoch 34/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0469 - mean_absolute_error: 0.1752
# Epoch 35/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0550 - mean_absolute_error: 0.1922
# Epoch 36/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0526 - mean_absolute_error: 0.1856
# Epoch 37/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0443 - mean_absolute_error: 0.1679
# Epoch 38/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0434 - mean_absolute_error: 0.1667
# Epoch 39/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0466 - mean_absolute_error: 0.1750
# Epoch 40/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0460 - mean_absolute_error: 0.1727
# Epoch 41/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0511 - mean_absolute_error: 0.1845
# Epoch 42/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0521 - mean_absolute_error: 0.1829
# Epoch 43/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0442 - mean_absolute_error: 0.1674
# Epoch 44/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0385 - mean_absolute_error: 0.1586
# Epoch 45/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0482 - mean_absolute_error: 0.1755
# Epoch 46/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0444 - mean_absolute_error: 0.1680
# Epoch 47/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0506 - mean_absolute_error: 0.1766
# Epoch 48/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0443 - mean_absolute_error: 0.1697
# Epoch 49/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0450 - mean_absolute_error: 0.1717
# Epoch 50/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0441 - mean_absolute_error: 0.1683
# Epoch 51/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0464 - mean_absolute_error: 0.1711
# Epoch 52/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0428 - mean_absolute_error: 0.1668
# Epoch 53/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0476 - mean_absolute_error: 0.1750
# Epoch 54/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0376 - mean_absolute_error: 0.1523
# Epoch 55/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0520 - mean_absolute_error: 0.1787
# Epoch 56/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0467 - mean_absolute_error: 0.1786

# %%
plt.figure(figsize=(12, 8))
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
# Creating a testing set with 60 time-steps and 1 output
time_steps = 30
test_data = conversions_scaled_data[train_size - time_steps:, :]

x_test = []
y_test = []
n_cols = 1

for i in range(time_steps, len(test_data)):
    x_test.append(test_data[i-time_steps:i, 0:n_cols])
    y_test.append(test_data[i, 0:n_cols])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_cols))

# %%
x_test.shape , y_test.shape
# Out:
# ((36, 30, 1), (36, 1))

# %%
predictions = model.predict(x_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 496ms/step

# %%
#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# (36, 1)

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform(y_test)

RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 0.77

# %%
preds_acts = pd.DataFrame(data={'Predicted conversions':predictions.flatten(), 'Actual conversions':y_test.flatten()})
preds_acts
# Out:
#     Predicted conversions  Actual conversions
# 0                5.986766           10.079527
# 1                6.207635            4.868349
# 2                6.169028            9.134768
# 3                6.210031            6.891433
# 4                6.208436            6.016440
# 5                6.097126            5.166667
# 6                5.863034            4.321665
# 7                5.563866            6.358181
# 8                5.345373            4.522599
# 9                5.093373            5.234060
# 10               4.946280            9.095239
# 11               5.092568           10.127772
# 12               5.457277            4.161246
# 13               5.565380            4.998920
# 14               5.588218            4.000000
# 15               5.440929            1.000000
# 16               5.081638            3.002452
# 17               4.730548            6.543285
# 18               4.640011            1.250000
# 19               4.411937            4.333333
# 20               4.314105            3.004196
# 21               4.250983            3.404269
# 22               4.239252            3.061707
# 23               4.214260            1.000000
# 24               4.078935            3.000000
# 25               4.030674            2.000000
# 26               4.031660            2.000000
# 27               4.029238            3.000000
# 28               4.108852            1.333334
# 29               4.098417            5.000000
# 30               4.283581            2.915050
# 31               4.447846            1.100247
# 32               4.497102            0.501860
# 33               4.387715            2.835140
# 34               4.370423            1.000000
# 35               4.289372            3.495456

# %%
train = conversionsdataset.iloc[:train_size , 0:1]
test = conversionsdataset.iloc[train_size: , 0:1]
test['Predicted conversions'] = predictions

plt.figure(figsize= (16, 6))
plt.title('conversions Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('conversions', fontsize= 18)
plt.plot(train['conversions'], linewidth= 3)
plt.plot(test['conversions'], linewidth= 3)
plt.plot(test["Predicted conversions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])

# %% [markdown]
# ## Forecast Next 30 Days

# %%
from datetime import timedelta

# %%
def insert_end(Xin, new_input):
    timestep = 30
    for i in range(timestep - 1):
        Xin[:, i, :] = Xin[:, i+1, :]
    Xin[:, timestep - 1, :] = new_input
    return Xin

# %%
future = 15*2
forcast = []
Xin = x_test[-1 :, :, :]
time = []
for i in range(0, future):
    out = model.predict(Xin, batch_size=5)
    forcast.append(out[0, 0]) 
    print(forcast)
    Xin = insert_end(Xin, out[0, 0]) 
    time.append(pd.to_datetime(conversionsdataset.index[-1]) + timedelta(days=i))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [0.32680938]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [0.32680938, 0.33446127]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [0.32680938, 0.33446127, 0.3502925]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597, 0.45646924]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597, 0.45646924, 0.44739878]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597, 0.45646924, 0.44739878, 0.43785492]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597, 0.45646924, 0.44739878, 0.43785492, 0.42890143]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597, 0.45646924, 0.44739878, 0.43785492, 0.42890143, 0.41923246]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597, 0.45646924, 0.44739878, 0.43785492, 0.42890143, 0.41923246, 0.41049773]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597, 0.45646924, 0.44739878, 0.43785492, 0.42890143, 0.41923246, 0.41049773, 0.4025359]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597, 0.45646924, 0.44739878, 0.43785492, 0.42890143, 0.41923246, 0.41049773, 0.4025359, 0.39520237]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597, 0.45646924, 0.44739878, 0.43785492, 0.42890143, 0.41923246, 0.41049773, 0.4025359, 0.39520237, 0.38978276]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597, 0.45646924, 0.44739878, 0.43785492, 0.42890143, 0.41923246, 0.41049773, 0.4025359, 0.39520237, 0.38978276, 0.38420156]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597, 0.45646924, 0.44739878, 0.43785492, 0.42890143, 0.41923246, 0.41049773, 0.4025359, 0.39520237, 0.38978276, 0.38420156, 0.38100567]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597, 0.45646924, 0.44739878, 0.43785492, 0.42890143, 0.41923246, 0.41049773, 0.4025359, 0.39520237, 0.38978276, 0.38420156, 0.38100567, 0.3799471]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597, 0.45646924, 0.44739878, 0.43785492, 0.42890143, 0.41923246, 0.41049773, 0.4025359, 0.39520237, 0.38978276, 0.38420156, 0.38100567, 0.3799471, 0.38041064]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [0.32680938, 0.33446127, 0.3502925, 0.3692484, 0.39046323, 0.41084948, 0.4278688, 0.44212794, 0.45599738, 0.46599126, 0.47293037, 0.47768816, 0.47835308, 0.4748336, 0.47122958, 0.46430597, 0.45646924, 0.44739878, 0.43785492, 0.42890143, 0.41923246, 0.41049773, 0.4025359, 0.39520237, 0.38978276, 0.38420156, 0.38100567, 0.3799471, 0.38041064, 0.3811224]

# %%
time
# Out:
# [Timestamp('2024-05-21 00:00:00'),
#  Timestamp('2024-05-22 00:00:00'),
#  Timestamp('2024-05-23 00:00:00'),
#  Timestamp('2024-05-24 00:00:00'),
#  Timestamp('2024-05-25 00:00:00'),
#  Timestamp('2024-05-26 00:00:00'),
#  Timestamp('2024-05-27 00:00:00'),
#  Timestamp('2024-05-28 00:00:00'),
#  Timestamp('2024-05-29 00:00:00'),
#  Timestamp('2024-05-30 00:00:00'),
#  Timestamp('2024-05-31 00:00:00'),
#  Timestamp('2024-06-01 00:00:00'),
#  Timestamp('2024-06-02 00:00:00'),
#  Timestamp('2024-06-03 00:00:00'),
#  Timestamp('2024-06-04 00:00:00'),
#  Timestamp('2024-06-05 00:00:00'),
#  Timestamp('2024-06-06 00:00:00'),
#  Timestamp('2024-06-07 00:00:00'),
#  Timestamp('2024-06-08 00:00:00'),
#  Timestamp('2024-06-09 00:00:00'),
#  Timestamp('2024-06-10 00:00:00'),
#  Timestamp('2024-06-11 00:00:00'),
#  Timestamp('2024-06-12 00:00:00'),
#  Timestamp('2024-06-13 00:00:00'),
#  Timestamp('2024-06-14 00:00:00'),
#  Timestamp('2024-06-15 00:00:00'),
#  Timestamp('2024-06-16 00:00:00'),
#  Timestamp('2024-06-17 00:00:00'),
#  Timestamp('2024-06-18 00:00:00'),
#  Timestamp('2024-06-19 00:00:00')]

# %%
forcasted_output = np.asanyarray(forcast)   
forcasted_output = forcasted_output.reshape(-1, 1) 
forcasted_output = scaler.inverse_transform(forcasted_output)

# %%
forcasted_output = pd.DataFrame(forcasted_output)
date = pd.DataFrame(time)
df_result = pd.concat([date,forcasted_output], axis=1)
df_result.columns = "Date", "Forecasted"

# %%
df_result
# Out:
#          Date  Forecasted
# 0  2024-05-21    4.289373
# 1  2024-05-22    4.389804
# 2  2024-05-23    4.597589
# 3  2024-05-24    4.846385
# 4  2024-05-25    5.124830
# 5  2024-05-26    5.392399
# 6  2024-05-27    5.615778
# 7  2024-05-28    5.802929
# 8  2024-05-29    5.984966
# 9  2024-05-30    6.116135
# 10 2024-05-31    6.207211
# 11 2024-06-01    6.269657
# 12 2024-06-02    6.278384
# 13 2024-06-03    6.232191
# 14 2024-06-04    6.184888
# 15 2024-06-05    6.094016
# 16 2024-06-06    5.991159
# 17 2024-06-07    5.872109
# 18 2024-06-08    5.746846
# 19 2024-06-09    5.629331
# 20 2024-06-10    5.502426
# 21 2024-06-11    5.387783
# 22 2024-06-12    5.283284
# 23 2024-06-13    5.187031
# 24 2024-06-14    5.115899
# 25 2024-06-15    5.042645
# 26 2024-06-16    5.000700
# 27 2024-06-17    4.986805
# 28 2024-06-18    4.992890
# 29 2024-06-19    5.002232

# %%
plt.figure(figsize=(16,8))
plt.title('conversions Forecasting For Next 30 Days')
plt.xlabel('Date', fontsize=18)
plt.ylabel('conversions' ,fontsize=18)
plt.plot(conversionsdataset['conversions'])
plt.plot(df_result.set_index('Date')[['Forecasted']])
