# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv('Data.csv')
df.head()
# Out:
#           Day Campaign status                   Campaign Budget name  \
# 0  2023-11-18          Paused    New Arrivals 05/10/2023          --
# 1  2023-11-13          Paused    New Arrivals 05/10/2023          --
# 2  2024-01-02          Paused  Display-Campaign Group 01          --
# 3  2024-01-07          Paused  Display-Campaign Group 01          --
# 4  2023-10-10          Paused    New Arrivals 05/10/2023          --
#
#   Currency code  Budget Budget type  Status            Status reasons  Clicks  \
# 0           GBP     3.0       Daily  Paused  campaign paused; unknown       1
# 1           GBP     3.0       Daily  Paused  campaign paused; unknown       3
# 2           GBP     5.0       Daily  Paused  campaign paused; unknown       0
# 3           GBP     5.0       Daily  Paused  campaign paused; unknown       0
# 4           GBP     3.0       Daily  Paused  campaign paused; unknown      17
#
#      CTR  Avg. CPC  Impr.  Avg. cost  Cost  Conv. value Campaign type  \
# 0  0.62%      0.16    162       0.16  0.16         0.00      Shopping
# 1  1.15%      0.18    261       0.18  0.53         0.00      Shopping
# 2     --      0.00      0       0.00  0.00         0.00       Display
# 3     --      0.00      0       0.00  0.00         0.00       Display
# 4  0.72%      0.23   2373       0.23  3.83       118.46      Shopping
#
#   Bid strategy type Campaign group
# 0       Target ROAS             --
# 1       Target ROAS             --
# 2       Target ROAS             --
# 3       Target ROAS             --
# 4       Target ROAS             --

# %%
df.head(30)
# Out:
#            Day Campaign status                   Campaign Budget name  \
# 0   2023-11-18          Paused    New Arrivals 05/10/2023          --
# 1   2023-11-13          Paused    New Arrivals 05/10/2023          --
# 2   2024-01-02          Paused  Display-Campaign Group 01          --
# 3   2024-01-07          Paused  Display-Campaign Group 01          --
# 4   2023-10-10          Paused    New Arrivals 05/10/2023          --
# 5   2023-06-20          Paused  Display-Campaign Group 01          --
# 6   2023-10-07          Paused  Display-Campaign Group 01          --
# 7   2023-06-17          Paused  Display-Campaign Group 01          --
# 8   2023-07-07          Paused  Display-Campaign Group 01          --
# 9   2023-07-11          Paused  Display-Campaign Group 01          --
# 10  2023-08-09          Paused  Display-Campaign Group 01          --
# 11  2023-08-07          Paused    New Arrivals 05/10/2023          --
# 12  2023-08-20          Paused  Display-Campaign Group 01          --
# 13  2023-11-18          Paused  Display-Campaign Group 01          --
# 14  2023-12-17          Paused  Display-Campaign Group 01          --
# 15  2024-04-16          Paused  Display-Campaign Group 01          --
# 16  2023-09-11          Paused    New Arrivals 05/10/2023          --
# 17  2024-02-09          Paused    New Arrivals 05/10/2023          --
# 18  2023-12-18          Paused  Display-Campaign Group 01          --
# 19  2023-12-31          Paused  Display-Campaign Group 01          --
# 20  2023-11-19          Paused  Display-Campaign Group 01          --
# 21  2024-01-19          Paused  Display-Campaign Group 01          --
# 22  2023-05-19          Paused  Display-Campaign Group 01          --
# 23  2023-06-04          Paused  Display-Campaign Group 01          --
# 24  2023-10-04          Paused  Display-Campaign Group 01          --
# 25  2023-11-21          Paused  Display-Campaign Group 01          --
# 26  2023-08-17          Paused  Display-Campaign Group 01          --
# 27  2023-11-02          Paused  Display-Campaign Group 01          --
# 28  2023-07-21          Paused  Display-Campaign Group 01          --
# 29  2023-09-14          Paused  Display-Campaign Group 01          --
#
#    Currency code  Budget Budget type  Status            Status reasons  \
# 0            GBP     3.0       Daily  Paused  campaign paused; unknown
# 1            GBP     3.0       Daily  Paused  campaign paused; unknown
# 2            GBP     5.0       Daily  Paused  campaign paused; unknown
# 3            GBP     5.0       Daily  Paused  campaign paused; unknown
# 4            GBP     3.0       Daily  Paused  campaign paused; unknown
# 5            GBP     5.0       Daily  Paused  campaign paused; unknown
# 6            GBP     5.0       Daily  Paused  campaign paused; unknown
# 7            GBP     5.0       Daily  Paused  campaign paused; unknown
# 8            GBP     5.0       Daily  Paused  campaign paused; unknown
# 9            GBP     5.0       Daily  Paused  campaign paused; unknown
# 10           GBP     5.0       Daily  Paused  campaign paused; unknown
# 11           GBP     3.0       Daily  Paused  campaign paused; unknown
# 12           GBP     5.0       Daily  Paused  campaign paused; unknown
# 13           GBP     5.0       Daily  Paused  campaign paused; unknown
# 14           GBP     5.0       Daily  Paused  campaign paused; unknown
# 15           GBP     5.0       Daily  Paused  campaign paused; unknown
# 16           GBP     3.0       Daily  Paused  campaign paused; unknown
# 17           GBP     3.0       Daily  Paused  campaign paused; unknown
# 18           GBP     5.0       Daily  Paused  campaign paused; unknown
# 19           GBP     5.0       Daily  Paused  campaign paused; unknown
# 20           GBP     5.0       Daily  Paused  campaign paused; unknown
# 21           GBP     5.0       Daily  Paused  campaign paused; unknown
# 22           GBP     5.0       Daily  Paused  campaign paused; unknown
# 23           GBP     5.0       Daily  Paused  campaign paused; unknown
# 24           GBP     5.0       Daily  Paused  campaign paused; unknown
# 25           GBP     5.0       Daily  Paused  campaign paused; unknown
# 26           GBP     5.0       Daily  Paused  campaign paused; unknown
# 27           GBP     5.0       Daily  Paused  campaign paused; unknown
# 28           GBP     5.0       Daily  Paused  campaign paused; unknown
# 29           GBP     5.0       Daily  Paused  campaign paused; unknown
#
#     Clicks    CTR  Avg. CPC  Impr.  Avg. cost  Cost  Conv. value  \
# 0        1  0.62%      0.16    162       0.16  0.16         0.00
# 1        3  1.15%      0.18    261       0.18  0.53         0.00
# 2        0     --      0.00      0       0.00  0.00         0.00
# 3        0     --      0.00      0       0.00  0.00         0.00
# 4       17  0.72%      0.23   2373       0.23  3.83       118.46
# 5        4  0.28%      0.11   1411       0.11  0.44         0.00
# 6        0     --      0.00      0       0.00  0.00         0.00
# 7        0     --      0.00      0       0.00  0.00         0.00
# 8        0     --      0.00      0       0.00  0.00         0.00
# 9        0     --      0.00      0       0.00  0.00         0.00
# 10       0     --      0.00      0       0.00  0.00         0.00
# 11       0     --      0.00      0       0.00  0.00         0.00
# 12       0     --      0.00      0       0.00  0.00         0.00
# 13       0     --      0.00      0       0.00  0.00         0.00
# 14       0     --      0.00      0       0.00  0.00         0.00
# 15       0     --      0.00      0       0.00  0.00         0.00
# 16       0     --      0.00      0       0.00  0.00         0.00
# 17       0     --      0.00      0       0.00  0.00         0.00
# 18       0     --      0.00      0       0.00  0.00         0.00
# 19       0     --      0.00      0       0.00  0.00         0.00
# 20       0     --      0.00      0       0.00  0.00         0.00
# 21       0     --      0.00      0       0.00  0.00         0.00
# 22       0     --      0.00      0       0.00  0.00         0.00
# 23       0     --      0.00      0       0.00  0.00         0.00
# 24       0     --      0.00      0       0.00  0.00         0.00
# 25       0     --      0.00      0       0.00  0.00         0.00
# 26       0     --      0.00      0       0.00  0.00         0.00
# 27       0     --      0.00      0       0.00  0.00         0.00
# 28       0     --      0.00      0       0.00  0.00         0.00
# 29       0     --      0.00      0       0.00  0.00         0.00
#
#    Campaign type Bid strategy type Campaign group
# 0       Shopping       Target ROAS             --
# 1       Shopping       Target ROAS             --
# 2        Display       Target ROAS             --
# 3        Display       Target ROAS             --
# 4       Shopping       Target ROAS             --
# 5        Display       Target ROAS             --
# 6        Display       Target ROAS             --
# 7        Display       Target ROAS             --
# 8        Display       Target ROAS             --
# 9        Display       Target ROAS             --
# 10       Display       Target ROAS             --
# 11      Shopping       Target ROAS             --
# 12       Display       Target ROAS             --
# 13       Display       Target ROAS             --
# 14       Display       Target ROAS             --
# 15       Display       Target ROAS             --
# 16      Shopping       Target ROAS             --
# 17      Shopping       Target ROAS             --
# 18       Display       Target ROAS             --
# 19       Display       Target ROAS             --
# 20       Display       Target ROAS             --
# 21       Display       Target ROAS             --
# 22       Display       Target ROAS             --
# 23       Display       Target ROAS             --
# 24       Display       Target ROAS             --
# 25       Display       Target ROAS             --
# 26       Display       Target ROAS             --
# 27       Display       Target ROAS             --
# 28       Display       Target ROAS             --
# 29       Display       Target ROAS             --

# %%
# all columns 
print(list(df.columns))

# shape of data
print(f'The dataset has shape {df.shape}')
# Out:
# ['Day', 'Campaign status', 'Campaign', 'Budget name', 'Currency code', 'Budget', 'Budget type', 'Status', 'Status reasons', 'Clicks', 'CTR', 'Avg. CPC', 'Impr.', 'Avg. cost', 'Cost', 'Conv. value', 'Campaign type', 'Bid strategy type', 'Campaign group']
# The dataset has shape (89915, 19)

# %% [markdown]
# # preprocessing

# %%
newData=df.sort_values(by=['Day'], ascending=True)
newData.head()
# Out:
#               Day Campaign status  \
# 26137  2023-05-15         Enabled
# 63686  2023-05-15         Enabled
# 19789  2023-05-15         Enabled
# 63503  2023-05-15         Removed
# 32070  2023-05-15         Removed
#
#                                                Campaign Budget name  \
# 26137                 Shoptimised_Performance Max-Thars          --
# 63686      Google css-S_opt-All- P_MAX -5/3/2024~susain          --
# 19789                               P_MAX - FR Merchant          --
# 63503       Performance Max-24 Transformer Product hero          --
# 32070  GOOGLE CSS- manuval CPC TO ROAS- Susain 23/02/24          --
#
#       Currency code  Budget Budget type               Status  \
# 26137           GBP     5.0       Daily  Eligible (Learning)
# 63686           GBP     2.0       Daily             Eligible
# 19789           GBP     2.0       Daily             Eligible
# 63503           GBP     8.0       Daily              Removed
# 32070           GBP    15.0       Daily              Removed
#
#                            Status reasons  Clicks CTR  Avg. CPC  Impr.  \
# 26137  bidding strategy learning; unknown       0  --       0.0      0
# 63686                             unknown       0  --       0.0      0
# 19789                             unknown       0  --       0.0      0
# 63503                    campaign removed       0  --       0.0      0
# 32070           campaign removed; unknown       0  --       0.0      0
#
#        Avg. cost  Cost  Conv. value    Campaign type  \
# 26137        0.0   0.0          0.0  Performance Max
# 63686        0.0   0.0          0.0  Performance Max
# 19789        0.0   0.0          0.0  Performance Max
# 63503        0.0   0.0          0.0  Performance Max
# 32070        0.0   0.0          0.0         Shopping
#
#                Bid strategy type           Campaign group
# 26137  Maximize Conversion Value                       --
# 63686  Maximize Conversion Value  Google-CSS- All pro-SEP
# 19789  Maximize Conversion Value                       --
# 63503  Maximize Conversion Value                       --
# 32070                Target ROAS                       --

# %%
processingData=newData.drop(['Day','Campaign status','Campaign','Budget name','Currency code','Budget type','Status','Status reasons','CTR','Impr.','Cost','Campaign group','Campaign type',], axis='columns', inplace=False)

# %%
processingData.head()
# Out:
#        Budget  Clicks  Avg. CPC  Avg. cost  Conv. value  \
# 26137     5.0       0       0.0        0.0          0.0
# 63686     2.0       0       0.0        0.0          0.0
# 19789     2.0       0       0.0        0.0          0.0
# 63503     8.0       0       0.0        0.0          0.0
# 32070    15.0       0       0.0        0.0          0.0
#
#                Bid strategy type
# 26137  Maximize Conversion Value
# 63686  Maximize Conversion Value
# 19789  Maximize Conversion Value
# 63503  Maximize Conversion Value
# 32070                Target ROAS

# %%
processingData.isnull().sum()
# Out:
# Budget               0
# Clicks               0
# Avg. CPC             0
# Avg. cost            0
# Conv. value          0
# Bid strategy type    0
# dtype: int64

# %%
processingData.shape
# Out:
# (89915, 6)

# %%
processingData.duplicated().sum()
# Out:
# 85385

# %%
processingData=processingData.drop_duplicates()

# %%
processingData.shape
# Out:
# (4530, 6)

# %%
processingData
# Out:
#        Budget  Clicks  Avg. CPC  Avg. cost  Conv. value  \
# 26137     5.0       0      0.00       0.00          0.0
# 63686     2.0       0      0.00       0.00          0.0
# 63503     8.0       0      0.00       0.00          0.0
# 32070    15.0       0      0.00       0.00          0.0
# 31905    20.0       0      0.00       0.00          0.0
# ...       ...     ...       ...        ...          ...
# 25558     2.0       1      0.66       0.66          0.0
# 31187     5.0       2      0.28       0.28          0.0
# 65863    15.0       6      0.58       0.58          0.0
# 3169     20.0       3      0.34       0.34          0.0
# 89427     2.0       1      0.07       0.07          0.0
#
#                              Bid strategy type
# 26137                Maximize Conversion Value
# 63686                Maximize Conversion Value
# 63503                Maximize Conversion Value
# 32070                              Target ROAS
# 31905                Maximize Conversion Value
# ...                                        ...
# 25558                Maximize Conversion Value
# 31187  Maximize Conversion Value (Target ROAS)
# 65863                Maximize Conversion Value
# 3169                 Maximize Conversion Value
# 89427  Maximize Conversion Value (Target ROAS)
#
# [4530 rows x 6 columns]

# %%
# #as type is a categorical need to transform the categorical features into numerical
# from sklearn.preprocessing import LabelEncoder
# import pickle

# labelencoder = LabelEncoder()

# # Fit the encoder on your training data (e.g., 'my_column')
# labelencoder.fit(processingData['Campaign type'])

# processingData['encoded_campaign_type'] = labelencoder.transform(processingData['Campaign type'])
# # mapping_campaign_type = dict(zip(labelencoder.classes_, labelencoder.transform(labelencoder.classes_)))

# # # Save it to a file (e.g., 'label_mapping.pkl')
# # with open('mapping_campaign_type.pkl', 'wb') as file:
# #     pickle.dump(mapping_campaign_type, file)

# print(processingData['encoded_campaign_type'])

# %%
# import pickle

# # Load the mapping dictionary from the pickle file
# with open('mapping_campaign_type.pkl', 'rb') as file:
#     mapping_campaign_type = pickle.load(file)

# new_data['encoded_campaign_type'] = new_data['Campaign type'].map(mapping_campaign_type).fillna(-1)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# Fit the encoder on your training data (e.g., 'my_column')
le.fit(processingData['Bid strategy type'])

processingData['encoded_bid_strategy_type'] =le.transform(processingData['Bid strategy type'])
# mapping_bid_strategy_type = dict(zip(le.classes_, le.transform(le.classes_)))

# # Save it to a file (e.g., 'label_mapping.pkl')
# with open('mapping_bid_strategy_type.pkl', 'wb') as file:
#     pickle.dump(mapping_bid_strategy_type, file)

print(processingData['encoded_bid_strategy_type'])
# Out:
# 26137    2
# 63686    2
# 63503    2
# 32070    8
# 31905    2
#         ..
# 25558    2
# 31187    3
# 65863    2
# 3169     2
# 89427    3
# Name: encoded_bid_strategy_type, Length: 4530, dtype: int32

# %%
# import pickle

# # Load the mapping dictionary from the pickle file
# with open('mapping_bid_strategy_type.pkl', 'rb') as file:
#     mapping_bid_strategy_type = pickle.load(file)

# new_data['encoded_bid_strategy_type'] = new_data['Bid strategy type'].map(mapping_bid_strategy_type).fillna(-1)

# %%
processingData.head()
# Out:
#        Budget  Clicks  Avg. CPC  Avg. cost  Conv. value  \
# 26137     5.0       0       0.0        0.0          0.0
# 63686     2.0       0       0.0        0.0          0.0
# 63503     8.0       0       0.0        0.0          0.0
# 32070    15.0       0       0.0        0.0          0.0
# 31905    20.0       0       0.0        0.0          0.0
#
#                Bid strategy type  encoded_bid_strategy_type
# 26137  Maximize Conversion Value                          2
# 63686  Maximize Conversion Value                          2
# 63503  Maximize Conversion Value                          2
# 32070                Target ROAS                          8
# 31905  Maximize Conversion Value                          2

# %%
cleanedData=processingData.drop(['Bid strategy type'], axis='columns', inplace=False)
cleanedData.head()
# Out:
#        Budget  Clicks  Avg. CPC  Avg. cost  Conv. value  \
# 26137     5.0       0       0.0        0.0          0.0
# 63686     2.0       0       0.0        0.0          0.0
# 63503     8.0       0       0.0        0.0          0.0
# 32070    15.0       0       0.0        0.0          0.0
# 31905    20.0       0       0.0        0.0          0.0
#
#        encoded_bid_strategy_type
# 26137                          2
# 63686                          2
# 63503                          2
# 32070                          8
# 31905                          2

# %%
cleanedData.isna().sum()
# Out:
# Budget                       0
# Clicks                       0
# Avg. CPC                     0
# Avg. cost                    0
# Conv. value                  0
# encoded_bid_strategy_type    0
# dtype: int64

# %%
y=cleanedData['Conv. value']
X=cleanedData.drop('Conv. value',axis='columns',inplace=False)

# %%
X
# Out:
#        Budget  Clicks  Avg. CPC  Avg. cost  encoded_bid_strategy_type
# 26137     5.0       0      0.00       0.00                          2
# 63686     2.0       0      0.00       0.00                          2
# 63503     8.0       0      0.00       0.00                          2
# 32070    15.0       0      0.00       0.00                          8
# 31905    20.0       0      0.00       0.00                          2
# ...       ...     ...       ...        ...                        ...
# 25558     2.0       1      0.66       0.66                          2
# 31187     5.0       2      0.28       0.28                          3
# 65863    15.0       6      0.58       0.58                          2
# 3169     20.0       3      0.34       0.34                          2
# 89427     2.0       1      0.07       0.07                          3
#
# [4530 rows x 5 columns]

# %%
X['CTR']=X['CTR'].str.replace(r'--', r'0.00')

# %%
X['CTR'] = (pd.to_numeric(X['CTR'].str[:-1])
                            .div(100)
                            .mask(X['CTR'] == '%', 0))

# %%
X
# Out:
#        Budget  Clicks  Avg. CPC  Avg. cost  encoded_bid_strategy_type
# 26137     5.0       0      0.00       0.00                          2
# 63686     2.0       0      0.00       0.00                          2
# 63503     8.0       0      0.00       0.00                          2
# 32070    15.0       0      0.00       0.00                          8
# 31905    20.0       0      0.00       0.00                          2
# ...       ...     ...       ...        ...                        ...
# 25558     2.0       1      0.66       0.66                          2
# 31187     5.0       2      0.28       0.28                          3
# 65863    15.0       6      0.58       0.58                          2
# 3169     20.0       3      0.34       0.34                          2
# 89427     2.0       1      0.07       0.07                          3
#
# [4530 rows x 5 columns]

# %%
y
# Out:
# 26137    0.0
# 63686    0.0
# 63503    0.0
# 32070    0.0
# 31905    0.0
#         ...
# 25558    0.0
# 31187    0.0
# 65863    0.0
# 3169     0.0
# 89427    0.0
# Name: Conv. value, Length: 4530, dtype: float64

# %%
print("shape of the x : ",X.shape)
print("shape of the y : ",y.shape)
# Out:
# shape of the x :  (4530, 5)
# shape of the y :  (4530,)

# %% [markdown]
# # linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
print("x_train: " + str(X_train.shape))
print("x_test: " + str(X_test.shape))
print("y_train: " + str(y_train.shape))
print("y_test: " + str(y_test.shape))
# Out:
# x_train: (3397, 5)
# x_test: (1133, 5)
# y_train: (3397,)
# y_test: (1133,)

# %%
X_train
# Out:
#        Budget  Clicks  Avg. CPC  Avg. cost  encoded_bid_strategy_type
# 15955    30.0      58      0.31       0.31                          2
# 3978     30.0      58      0.32       0.32                          2
# 29720     5.0      13      0.23       0.23                          2
# 15810     1.0       4      0.76       0.76                          3
# 8381      2.0      32      0.17       0.17                          8
# ...       ...     ...       ...        ...                        ...
# 4891      2.0      24      0.23       0.23                          0
# 2280      0.1       1      0.45       0.45                          8
# 31869    20.0      47      0.33       0.30                          2
# 26592     2.0       8      0.32       0.29                          2
# 33211     5.0       7      0.18       0.18                          0
#
# [3397 rows x 5 columns]

# %%
regr = LinearRegression().fit(X_train,y_train)

# %%
regr.score(X_test, y_test)
# Out:
# 0.31183226336200864

# %%
print('LR Coefficients: \n', regr.coef_)
print('LR Intercept: \n', regr.intercept_)
# Out:
# LR Coefficients:
#  [ -1.33833239   2.03443078  50.73588573 -43.80557679   2.57588412]
# LR Intercept:
#  -10.55056226895961

# %%
y_pred = regr.predict(X_test)

# %%
result=X_test

# %%
result['actual conversion value']=y_test

# %%
result['predicted conversion value']=y_pred

# %%
result
# Out:
#        Budget  Clicks  Avg. CPC  Avg. cost  encoded_bid_strategy_type  \
# 8519      2.0       3      0.15       0.15                          0
# 36714     5.0       3      0.45       0.45                          3
# 56441     3.0      13      0.40       0.40                          2
# 36703     5.0       5      0.36       0.36                          3
# 15025     5.0       8      0.75       0.75                          2
# ...       ...     ...       ...        ...                        ...
# 67800     3.9       3      0.89       0.89                          3
# 59674     0.1       2      0.10       0.10                          4
# 10915     6.0      33      0.41       0.41                          2
# 49350     0.5       7      0.16       0.16                          8
# 4513      2.0       9      0.55       0.55                          2
#
#        actual conversion value  predicted conversion value
# 8519                      0.00                   -6.084388
# 36714                     0.00                   -0.292641
# 56441                     8.67                   19.805932
# 36703                    12.29                    3.152493
# 15025                    59.50                    9.382722
# ...                        ...                         ...
# 67800                     0.00                    4.228861
# 59674                     0.00                    4.381033
# 10915                    25.49                   56.548854
# 49350                     0.00                   24.737209
# 4513                      0.00                   14.046088
#
# [1133 rows x 7 columns]

# %%
plt.scatter(X_test['Avg. cost'], y_test, color ='b')
plt.plot(X_test['Avg. cost'], y_pred, color ='k')
plt.show()

# %%
from sklearn import metrics
print("Training R-squared: ",round(metrics.r2_score(y_test,y_pred),2))
print("Training Explained Variation: ",round(metrics.explained_variance_score(y_test,y_pred),2))
print('Training MAPE:', round(metrics.mean_absolute_percentage_error(y_test,y_pred), 2)) 
print('Training Mean Squared Error:', round(metrics.mean_squared_error(y_test,y_pred), 2)) 
print("Training RMSE: ",round(np.sqrt(metrics.mean_squared_error(y_test,y_pred)),2))
print("Training MAE: ",round(metrics.mean_absolute_error(y_test,y_pred),2))
# Out:
# Training R-squared:  0.31
# Training Explained Variation:  0.31
# Training MAPE: 3.956326970421539e+16
# Training Mean Squared Error: 11963.97
# Training RMSE:  109.38
# Training MAE:  41.1
