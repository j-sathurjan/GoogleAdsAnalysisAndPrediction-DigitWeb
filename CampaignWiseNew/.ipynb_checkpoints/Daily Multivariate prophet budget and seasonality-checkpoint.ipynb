# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

import warnings
warnings.simplefilter('ignore')
from prophet import Prophet

# %%
#read the data
df = pd.read_csv("DailyDataFinal.csv", parse_dates=['date'], delimiter=',')

# %%
#check the dtypes
print(df.dtypes)
# Out:
# campaign name                           object
# date                            datetime64[ns]
# clicks                                   int64
# impressions                              int64
# cost_micros                              int64
# bidding_strategy_type                   object
# conversions                            float64
# cost_per_conversion                    float64
# Click-through rate (CTR)               float64
# average cost per click (CPC)           float64
# cost-per-acquisition (CPA)             float64
# Cost                                   float64
# conversion_per_euro                    float64
# budget                                   int64
# isholiday                                int64
# dtype: object

# %%
df['date'] = pd.to_datetime(df.date , format = '%d/%m/%Y %H.%M.%S')

# %%
plt.scatter(df['budget'],df['Cost'],label=df.index)
# for i, name in enumerate(df.index):
#     plt.annotate(name, (df.budget[i], df.Cost[i]), textcoords="offset points", xytext=(0, 5), ha='center')

# Customize plot (add labels, title, etc.)
plt.xlabel('Budget')
plt.ylabel('Cost')
plt.title('Cost Vs Budget')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.head(3)
# Out:
#                           campaign name       date  clicks  impressions  \
# 0  SHOPTIMISED PMax-46 - all products-M 2023-11-28       0           33
# 1  SHOPTIMISED PMax-46 - all products-M 2023-11-29      11         1139
# 2  SHOPTIMISED PMax-46 - all products-M 2023-11-30       7          655
#
#    cost_micros      bidding_strategy_type  conversions  cost_per_conversion  \
# 0            0  MAXIMIZE_CONVERSION_VALUE          0.0                  NaN
# 1      4060000  MAXIMIZE_CONVERSION_VALUE          1.0            4060000.0
# 2      1430000  MAXIMIZE_CONVERSION_VALUE          0.0                  NaN
#
#    Click-through rate (CTR)  average cost per click (CPC)  \
# 0                  0.000000                      0.000000
# 1                  0.965759                      0.369091
# 2                  1.068702                      0.204286
#
#    cost-per-acquisition (CPA)  Cost  conversion_per_euro  budget  isholiday
# 0                    0.000000  0.00             0.000000       5          0
# 1                    4.060000  4.06             0.246305       2          0
# 2                    4.085714  1.43             0.000000       2          0

# %%
df.drop(['campaign name','clicks','impressions','cost_micros','bidding_strategy_type','cost_per_conversion','Click-through rate (CTR)','average cost per click (CPC)','cost-per-acquisition (CPA)','conversion_per_euro','Cost'],axis=1, inplace=True)

# %%
df.head(5)
# Out:
#         date  conversions  budget  isholiday
# 0 2023-11-28     0.000000       5          0
# 1 2023-11-29     1.000000       2          0
# 2 2023-11-30     0.000000       2          0
# 3 2023-12-01     0.000000       7          0
# 4 2023-12-02     3.332276       7          0

# %%
df.date.dt.year
# Out:
# 0      2023
# 1      2023
# 2      2023
# 3      2023
# 4      2023
#        ...
# 176    2024
# 177    2024
# 178    2024
# 179    2024
# 180    2024
# Name: date, Length: 181, dtype: int32

# %%
df['year']=df.date.dt.year
df['month']=df.date.dt.month
df['day']=df.date.dt.day
df['week']=df.date.dt.dayofweek

# %%
df
# Out:
#           date  conversions  budget  isholiday  year  month  day  week
# 0   2023-11-28     0.000000       5          0  2023     11   28     1
# 1   2023-11-29     1.000000       2          0  2023     11   29     2
# 2   2023-11-30     0.000000       2          0  2023     11   30     3
# 3   2023-12-01     0.000000       7          0  2023     12    1     4
# 4   2023-12-02     3.332276       7          0  2023     12    2     5
# ..         ...          ...     ...        ...   ...    ...  ...   ...
# 176 2024-05-22     1.000000      20          0  2024      5   22     2
# 177 2024-05-23     2.000000      20          0  2024      5   23     3
# 178 2024-05-24     1.000000      20          0  2024      5   24     4
# 179 2024-05-25     0.998544      20          0  2024      5   25     5
# 180 2024-05-26     3.250000      20          0  2024      5   26     6
#
# [181 rows x 8 columns]

# %%
def applyer(row):
    if row.dayofweek==5 or row.dayofweek==6:
        return 1
    else:
        return 0

# %%
df['isweekend']=df['date'].apply(applyer)
df
# Out:
#           date  conversions  budget  isholiday  year  month  day  week  \
# 0   2023-11-28     0.000000       5          0  2023     11   28     1
# 1   2023-11-29     1.000000       2          0  2023     11   29     2
# 2   2023-11-30     0.000000       2          0  2023     11   30     3
# 3   2023-12-01     0.000000       7          0  2023     12    1     4
# 4   2023-12-02     3.332276       7          0  2023     12    2     5
# ..         ...          ...     ...        ...   ...    ...  ...   ...
# 176 2024-05-22     1.000000      20          0  2024      5   22     2
# 177 2024-05-23     2.000000      20          0  2024      5   23     3
# 178 2024-05-24     1.000000      20          0  2024      5   24     4
# 179 2024-05-25     0.998544      20          0  2024      5   25     5
# 180 2024-05-26     3.250000      20          0  2024      5   26     6
#
#      isweekend
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
# ..         ...
# 176          0
# 177          0
# 178          0
# 179          1
# 180          1
#
# [181 rows x 9 columns]

# %% [markdown]
# ## conversion

# %%
conv =df.rename(columns={'date': 'ds', 'conversions': 'y'})

# %%
#creating the train and validation set
train = conv[:int(0.8*(len(conv)))]
valid = conv[int(0.8*(len(conv))):]

# %%
train.dtypes
# Out:
# ds           datetime64[ns]
# y                   float64
# budget                int64
# isholiday             int64
# year                  int32
# month                 int32
# day                   int32
# week                  int32
# isweekend             int64
# dtype: object

# %%
train.head(5)
# Out:
#           ds         y  budget  isholiday  year  month  day  week  isweekend
# 0 2023-11-28  0.000000       5          0  2023     11   28     1          0
# 1 2023-11-29  1.000000       2          0  2023     11   29     2          0
# 2 2023-11-30  0.000000       2          0  2023     11   30     3          0
# 3 2023-12-01  0.000000       7          0  2023     12    1     4          0
# 4 2023-12-02  3.332276       7          0  2023     12    2     5          1

# %%
plt.figure(figsize = (15, 6))
plt.plot(train['ds'], train['y'])
plt.xlabel('Date', {'fontsize': 12})
plt.ylabel('conversions', {'fontsize': 12})
plt.title('Number of conversions')
plt.show()

# %%
from prophet.make_holidays import make_holidays_df

uk_holidays = make_holidays_df(
    year_list=[2023,2024], country='GB'
)
uk_holidays.head()
# Out:
#           ds              holiday
# 0 2024-03-29          Good Friday
# 1 2024-05-06              May Day
# 2 2024-05-27  Spring Bank Holiday
# 3 2024-01-01       New Year's Day
# 4 2024-12-25        Christmas Day

# %%
def is_nfl_season(ds):
    date = pd.to_datetime(ds)
    return (date.month > 9 or date.month < 3)

train['on_season'] = train['ds'].apply(is_nfl_season)
train['off_season'] = ~train['ds'].apply(is_nfl_season)

# %%
def is_peak(ds):
    date = pd.to_datetime(ds)
    if (date.month > 9 or date.month < 3):
        return 1
    else:
        return 0

# %%
train['ispeak'] = train['ds'].apply(is_peak)

# %%
train
# Out:
#             ds          y  budget  isholiday  year  month  day  week  \
# 0   2023-11-28   0.000000       5          0  2023     11   28     1
# 1   2023-11-29   1.000000       2          0  2023     11   29     2
# 2   2023-11-30   0.000000       2          0  2023     11   30     3
# 3   2023-12-01   0.000000       7          0  2023     12    1     4
# 4   2023-12-02   3.332276       7          0  2023     12    2     5
# ..         ...        ...     ...        ...   ...    ...  ...   ...
# 139 2024-04-15  10.476022      50          0  2024      4   15     0
# 140 2024-04-16  10.079527      50          0  2024      4   16     1
# 141 2024-04-17   4.868349      50          0  2024      4   17     2
# 142 2024-04-18   9.134768      50          0  2024      4   18     3
# 143 2024-04-19   6.891433      50          0  2024      4   19     4
#
#      isweekend  on_season  off_season  ispeak
# 0            0       True       False       1
# 1            0       True       False       1
# 2            0       True       False       1
# 3            0       True       False       1
# 4            1       True       False       1
# ..         ...        ...         ...     ...
# 139          0      False        True       0
# 140          0      False        True       0
# 141          0      False        True       0
# 142          0      False        True       0
# 143          0      False        True       0
#
# [144 rows x 12 columns]

# %%
#fit the model
model = Prophet(holidays=uk_holidays,holidays_prior_scale=0.05)
model.add_regressor('budget')
model.add_country_holidays(country_name='GB')
# model.add_seasonality(name='monthly',period=30.5,fourier_order=5)
# model.add_seasonality(name='monthly_on_season',period=30.5,fourier_order=5,condition_name='on_season')
# model.add_seasonality(name='monthly_off_season',period=30.5,fourier_order=5,condition_name='off_season')
# model.add_seasonality(name='weekly_on_season',period=7,fourier_order=3,condition_name='on_season')
# model.add_seasonality(name='weekly_off_season',period=7,fourier_order=3,condition_name='off_season')
# model.add_seasonality(name='weekly',period=7,fourier_order=3,prior_scale=0.1)

# model.add_regressor('isholiday')
model.add_regressor('year')
model.add_regressor('month')
model.add_regressor('day')
model.add_regressor('week')
model.add_regressor('isweekend')
model.add_regressor('ispeak')
model.fit(train)
# Out:
# 17:55:28 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:28 - cmdstanpy - INFO - Chain [1] done processing

# %%
valid['on_season'] = valid['ds'].apply(is_nfl_season)
valid['off_season'] = ~valid['ds'].apply(is_nfl_season)
valid['ispeak'] = valid['ds'].apply(is_peak)
valid_predict=model.predict(valid.drop('y',axis=1))

# %%
model.plot(valid_predict)

# %%
model.plot_components(valid_predict)

# %%
# from prophet.plot import plot_yearly
# a = plot_yearly(model)

# %%
predicted=pd.DataFrame()
predicted['date']=valid_predict.ds
predicted['conversions']=valid_predict.yhat
predicted['budget']=valid_predict.budget
# predicted['isholiday']=valid_predict.isholiday
# predicted['year']=valid_predict.year
# predicted['month']=valid_predict.month
# predicted['day']=valid_predict.day
# predicted['week']=valid_predict.week
# predicted['isweekend']=valid_predict.isweekend

# %%
actual=pd.DataFrame()
actual['date']=valid.ds
actual['conversions']=valid.y
actual['budget']=valid.budget
# actual['isholiday']=valid.isholiday
# actual['year']=valid.year
# actual['month']=valid.month
# actual['day']=valid.day
# actual['week']=valid.week
# actual['isweekend']=valid.isweekend

# %%
actual.set_index(actual.date,inplace=True)
predicted.set_index(predicted.date,inplace=True)
# actual

# %%
# predicted

# %%
#Combine the actual result and predicted result side by side
result=pd.DataFrame()

result['Actual Conversions']=actual['conversions']
result['PredictedConversions']=predicted['conversions']

# result['Actual Cost']=actual['cost']
# result['Predicted Cost']=predicted['cost']

# result['Actual week']=actual['week']
# result['Predicted week']=predicted['week']

# %%
result.tail(30)
# Out:
#             Actual Conversions  PredictedConversions
# date
# 2024-04-27           10.127772              4.373760
# 2024-04-28            4.161246              4.329133
# 2024-04-29            4.998920              3.933641
# 2024-04-30            4.000000              3.889015
# 2024-05-01            1.000000              5.264961
# 2024-05-02            3.002452              5.220334
# 2024-05-03            6.543285              4.129068
# 2024-05-04            1.250000              4.369790
# 2024-05-05            4.333333              4.325164
# 2024-05-06            3.004196              3.929672
# 2024-05-07            3.404269              3.885045
# 2024-05-08            3.061707              3.840419
# 2024-05-09            1.000000              3.795792
# 2024-05-10            3.000000              3.751166
# 2024-05-11            2.000000              3.991887
# 2024-05-12            2.000000              3.947261
# 2024-05-13            3.000000              3.551769
# 2024-05-14            1.333334              3.507142
# 2024-05-15            5.005930              3.462516
# 2024-05-16            2.915050              3.417889
# 2024-05-17            1.100247              3.373263
# 2024-05-18            1.501860              3.613985
# 2024-05-19            2.835140              3.569358
# 2024-05-20            1.000000              3.173866
# 2024-05-21            4.500454              3.129240
# 2024-05-22            1.000000              3.084613
# 2024-05-23            2.000000              3.039987
# 2024-05-24            1.000000              2.995360
# 2024-05-25            0.998544              3.236082
# 2024-05-26            3.250000              3.191455

# %%
#check rmse
cols = train.columns
from math import sqrt
from sklearn.metrics import mean_squared_error, mean_absolute_error

print('rmse value is : ', sqrt(mean_squared_error(result['Actual Conversions'],result['PredictedConversions'])))
print('mse value is : ', mean_squared_error(result['Actual Conversions'],result['PredictedConversions']))
print('mean absolute error is : ', mean_absolute_error(result['Actual Conversions'], result['PredictedConversions']))
# Out:
# rmse value is :  2.1000145642403663
# mse value is :  4.410061170021655
# mean absolute error is :  1.6356173912333567

# %%
finalModel = Prophet()
finalModel.add_regressor('budget')
finalModel.add_regressor('isholiday')
finalModel.add_regressor('year')
finalModel.add_regressor('month')
finalModel.add_regressor('day')
finalModel.add_regressor('week')
finalModel.add_regressor('isweekend')
finalModel.fit(conv)
# Out:
# 17:32:05 - cmdstanpy - INFO - Chain [1] start processing
# 17:32:05 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = finalModel.make_future_dataframe(periods=10)
future['budget']=20
future['isholiday']=0
future['year']=future.ds.dt.year
future['month']=future.ds.dt.month
future['day']=future.ds.dt.day
future['week']=future.ds.dt.dayofweek
future['isweekend']=future.ds.apply(applyer)
future.tail(15)
# Out:
#             ds  budget  isholiday  year  month  day  week  isweekend
# 176 2024-05-22      20          0  2024      5   22     2          0
# 177 2024-05-23      20          0  2024      5   23     3          0
# 178 2024-05-24      20          0  2024      5   24     4          0
# 179 2024-05-25      20          0  2024      5   25     5          1
# 180 2024-05-26      20          0  2024      5   26     6          1
# 181 2024-05-27      20          0  2024      5   27     0          0
# 182 2024-05-28      20          0  2024      5   28     1          0
# 183 2024-05-29      20          0  2024      5   29     2          0
# 184 2024-05-30      20          0  2024      5   30     3          0
# 185 2024-05-31      20          0  2024      5   31     4          0
# 186 2024-06-01      20          0  2024      6    1     5          1
# 187 2024-06-02      20          0  2024      6    2     6          1
# 188 2024-06-03      20          0  2024      6    3     0          0
# 189 2024-06-04      20          0  2024      6    4     1          0
# 190 2024-06-05      20          0  2024      6    5     2          0

# %%
finalPrediction=model.predict(future)

# %%
finalPrediction.tail(15)
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 176 2024-05-22  4.608937   -0.962086    5.432045     4.608867     4.609004
# 177 2024-05-23  4.600673   -0.477690    5.884036     4.600601     4.600744
# 178 2024-05-24  4.592410   -0.497234    5.498063     4.592335     4.592484
# 179 2024-05-25  4.584147   -0.490674    5.895679     4.584069     4.584224
# 180 2024-05-26  4.575883    0.410274    6.798124     4.575803     4.575963
# 181 2024-05-27  4.567620   -0.340686    5.800605     4.567536     4.567703
# 182 2024-05-28  4.559356   -0.405176    5.781012     4.559270     4.559444
# 183 2024-05-29  4.551093   -1.187676    5.038820     4.551003     4.551185
# 184 2024-05-30  4.542830   -0.534381    5.579172     4.542735     4.542925
# 185 2024-05-31  4.534566   -1.355123    5.169809     4.534468     4.534665
# 186 2024-06-01  4.526303    0.703258    6.932788     4.526201     4.526403
# 187 2024-06-02  4.518039    1.329041    7.618045     4.517935     4.518144
# 188 2024-06-03  4.509776    0.678115    6.811663     4.509668     4.509884
# 189 2024-06-04  4.501513    0.772519    6.713856     4.501400     4.501624
# 190 2024-06-05  4.493249   -0.138770    6.209382     4.493133     4.493365
#
#      Boxing Day  Boxing Day_lower  Boxing Day_upper  Christmas Day  ...  \
# 176         0.0               0.0               0.0            0.0  ...
# 177         0.0               0.0               0.0            0.0  ...
# 178         0.0               0.0               0.0            0.0  ...
# 179         0.0               0.0               0.0            0.0  ...
# 180         0.0               0.0               0.0            0.0  ...
# 181         0.0               0.0               0.0            0.0  ...
# 182         0.0               0.0               0.0            0.0  ...
# 183         0.0               0.0               0.0            0.0  ...
# 184         0.0               0.0               0.0            0.0  ...
# 185         0.0               0.0               0.0            0.0  ...
# 186         0.0               0.0               0.0            0.0  ...
# 187         0.0               0.0               0.0            0.0  ...
# 188         0.0               0.0               0.0            0.0  ...
# 189         0.0               0.0               0.0            0.0  ...
# 190         0.0               0.0               0.0            0.0  ...
#
#        weekly  weekly_lower  weekly_upper      year  year_lower  year_upper  \
# 176 -0.687973     -0.687973     -0.687973  0.095324    0.095324    0.095324
# 177 -0.126427     -0.126427     -0.126427  0.095324    0.095324    0.095324
# 178 -0.336720     -0.336720     -0.336720  0.095324    0.095324    0.095324
# 179  0.143275      0.143275      0.143275  0.095324    0.095324    0.095324
# 180  0.909306      0.909306      0.909306  0.095324    0.095324    0.095324
# 181 -0.000639     -0.000639     -0.000639  0.095324    0.095324    0.095324
# 182  0.099178      0.099178      0.099178  0.095324    0.095324    0.095324
# 183 -0.687973     -0.687973     -0.687973  0.095324    0.095324    0.095324
# 184 -0.126427     -0.126427     -0.126427  0.095324    0.095324    0.095324
# 185 -0.336720     -0.336720     -0.336720  0.095324    0.095324    0.095324
# 186  0.143275      0.143275      0.143275  0.095324    0.095324    0.095324
# 187  0.909306      0.909306      0.909306  0.095324    0.095324    0.095324
# 188 -0.000639     -0.000639     -0.000639  0.095324    0.095324    0.095324
# 189  0.099178      0.099178      0.099178  0.095324    0.095324    0.095324
# 190 -0.687973     -0.687973     -0.687973  0.095324    0.095324    0.095324
#
#      multiplicative_terms  multiplicative_terms_lower  \
# 176                   0.0                         0.0
# 177                   0.0                         0.0
# 178                   0.0                         0.0
# 179                   0.0                         0.0
# 180                   0.0                         0.0
# 181                   0.0                         0.0
# 182                   0.0                         0.0
# 183                   0.0                         0.0
# 184                   0.0                         0.0
# 185                   0.0                         0.0
# 186                   0.0                         0.0
# 187                   0.0                         0.0
# 188                   0.0                         0.0
# 189                   0.0                         0.0
# 190                   0.0                         0.0
#
#      multiplicative_terms_upper      yhat
# 176                         0.0  2.328088
# 177                         0.0  2.811303
# 178                         0.0  2.522679
# 179                         0.0  2.779232
# 180                         0.0  3.466932
# 181                         0.0  2.782340
# 182                         0.0  2.803826
# 183                         0.0  1.938344
# 184                         0.0  2.421559
# 185                         0.0  2.132935
# 186                         0.0  3.805411
# 187                         0.0  4.493110
# 188                         0.0  3.808518
# 189                         0.0  3.830005
# 190                         0.0  2.964523
#
# [15 rows x 64 columns]

# %%
finalResult=pd.DataFrame()
finalResult['Date']=finalPrediction['ds']
finalResult['Forecasted Conversion']=finalPrediction['yhat']
finalResult['Actual Conversion']=conv.y

# %%
finalResult.tail(15)
# Out:
#           Date  Forecasted Conversion  Actual Conversion
# 176 2024-05-22               2.328088           1.000000
# 177 2024-05-23               2.811303           2.000000
# 178 2024-05-24               2.522679           1.000000
# 179 2024-05-25               2.779232           0.998544
# 180 2024-05-26               3.466932           3.250000
# 181 2024-05-27               2.782340                NaN
# 182 2024-05-28               2.803826                NaN
# 183 2024-05-29               1.938344                NaN
# 184 2024-05-30               2.421559                NaN
# 185 2024-05-31               2.132935                NaN
# 186 2024-06-01               3.805411                NaN
# 187 2024-06-02               4.493110                NaN
# 188 2024-06-03               3.808518                NaN
# 189 2024-06-04               3.830005                NaN
# 190 2024-06-05               2.964523                NaN
